# %%
import json
import azure_functions.shared_code.tw2html
from IPython.display import display, HTML

with open("azure_functions/local.settings.json",'r') as f:
    keys = json.load(f)["Values"]

twitter_keys = {
    'consumer_key': keys['api_key'],
    'consumer_secret':keys['api_secret'],
    'access_token': keys['access'],
    'access_token_secret' : keys['secret']
}
            
html = azure_functions.shared_code.tw2html.get_timeline_html(twitter_keys)
display(HTML(html))
# Out:
# <html lang="en">
# <style>
#
# .item  {border-style: solid; margin:10px; padding:5px}
# .item .text { width = 70%; float=right;}
# .item img { float=left; width:25%;}
#
# </style>
# <body>
#
# <div class=item>
#     <h3>Hlídač Státu</h3><h5>2022-04-27 07:27:05+00:00</h5>
#     <div class=text>
#     Dneska to bude na vládě nabyté! Ale hlavně se nám líbí první bod: open data! 😍 https://t.co/pFFQxv07Jl
#
#     </div>
#     <img src="http://pbs.twimg.com/media/FRVXGHvWUAAHlli.jpg" alt="img">
# </div>
#
# <div class=item>
#     <h3>Daniel Prokop</h3><h5>2022-04-27 07:20:20+00:00</h5>
#     <div class=text>
#     U slevy na poplatníka i rodičáku lze udělat opatření méně pro-inflační a cílené na chudší. Slevu převést do bonusu. V rodičáku zvednout dolní limit čerpání z 10 na 15 tisíc měsíčně. A vymyslet valorizační schéma dlouhododobé. https://t.co/U0OuWpysM4
#     <h4>Uris:</h4><ul><li><a href=https://twitter.com/kalousekm/status/1519210677126242304>https://twitter.com/kalousekm/status/1519210677126242304</a></li></ul>
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Česko ve fotografii</h3><h5>2022-04-27 06:05:03+00:00</h5>
#     <div class=text>
#     Měšťanský pivovar v Písku, před rokem 1887. Autor: Jan Vavruška. Uloženo ve Sbírce Scheufler https://t.co/1p9fxHWTo6 https://t.co/pd2UMRyAuH
#     <h4>Uris:</h4><ul><li><a href=http://buff.ly/2KuV5U8>http://buff.ly/2KuV5U8</a></li></ul>
#     </div>
#     <img src="http://pbs.twimg.com/media/FRVEn05XEAQRsud.jpg" alt="img">
# </div>
#
# <div class=item>
#     <h3>Randall Munroe</h3><h5>2022-04-27 03:36:43+00:00</h5>
#     <div class=text>
#     Never been as disappointed as when I searched YouTube for “human pronking” and nothing came up https://t.co/SMdYMCV32l
#
#     </div>
#     <img src="http://pbs.twimg.com/tweet_video_thumb/FRUip1HX0AEIqmB.jpg" alt="img">
# </div>
#
# <div class=item>
#     <h3>Computer Science</h3><h5>2022-04-26 20:55:01+00:00</h5>
#     <div class=text>
#     The problem of determining whether a graph has a Hamiltonian circuit is NP complete.
#
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Probability Fact</h3><h5>2022-04-26 20:15:04+00:00</h5>
#     <div class=text>
#     Alan Turing's statistical work during World War II https://t.co/5zKN26UZZq [pdf]
#     <h4>Uris:</h4><ul><li><a href=http://languagelog.ldc.upenn.edu/myl/Good1979.pdf>http://languagelog.ldc.upenn.edu/myl/Good1979.pdf</a></li></ul>
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Units</h3><h5>2022-04-26 19:01:18+00:00</h5>
#     <div class=text>
#     A pinch or a dash is 1/16 of a teaspoon.
#
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Signal Processing</h3><h5>2022-04-26 18:30:12+00:00</h5>
#     <div class=text>
#     Cepstrum, quefrency, and pitch https://t.co/QO5OCSsO6g
#     <h4>Uris:</h4><ul><li><a href=https://www.johndcook.com/blog/2016/05/18/cepstrum-quefrency-and-pitch/>https://www.johndcook.com/blog/2016/05/18/cepstrum-quefrency-and-pitch/</a></li></ul>
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Data Science Fact</h3><h5>2022-04-26 18:15:04+00:00</h5>
#     <div class=text>
#     Naive Bayes is called 'naive' because it assumes things are independent that definitely are not. And in the right setting works well anyway.
#
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>dendronhq</h3><h5>2022-04-26 18:11:13+00:00</h5>
#     <div class=text>
#     Dendron 0.92 has sprouted 🌱
#
# - 🚀 up to 100x speed-up in graph view 🌌
# - 🏄‍♀️ improved stability of tree view 🌴
# - 🔥 new feature for self contained vaults 🗃
# - 🐛 fixes and 📈 improvements
# - 🍃 Greenhouse talk this week!
#
# https://t.co/phwKxu7TYq
#     <h4>Uris:</h4><ul><li><a href=https://wiki.dendron.so/notes/2kb9bl9378k9w45wfrtkrnr/>https://wiki.dendron.so/notes/2kb9bl9378k9w45wfrtkrnr/</a></li></ul>
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Unix tool tip</h3><h5>2022-04-26 16:40:02+00:00</h5>
#     <div class=text>
#     In bash, cd - takes you back to your previous directory.
#
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Fermat's Library</h3><h5>2022-04-26 16:12:52+00:00</h5>
#     <div class=text>
#     In the 1950s, researchers at IBM demoed a computer program that could learn to play checkers well enough to beat its programmer
#
# Soon after, MIT prof. Norbert Wiener wrote an article warning about the consequences of developing machines that can learn
#
# 📝:
# https://t.co/UZ2ld1PgQa https://t.co/seCxPzUK8x
#     <h4>Uris:</h4><ul><li><a href=https://fermatslibrary.com/s/some-moral-and-technical-consequences-of-automation>https://fermatslibrary.com/s/some-moral-and-technical-consequences-of-automation</a></li></ul>
#     </div>
#     <img src="http://pbs.twimg.com/media/FRSGJqlXIAIPdnY.jpg" alt="img">
# </div>
#
# <div class=item>
#     <h3>Probability Fact</h3><h5>2022-04-26 16:03:04+00:00</h5>
#     <div class=text>
#     The Dirichlet distribution is conjugate to the multinomial distribution.
#
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Akademie věd ČR</h3><h5>2022-04-26 15:54:31+00:00</h5>
#     <div class=text>
#     Akademie věd ČR získala Cenu rektora @CZUvPraze. Univerzita ocenění předávala partnerským institucím, a to při příležitosti 70. výročí svého působení. Cenu za #AVČR přebíral předseda Vědecké rady AV ČR Pavel Baran.
# Více ➡️
# https://t.co/3uEEdBhw0O https://t.co/2LH7yo1MoJ
#     <h4>Uris:</h4><ul><li><a href=https://www.avcr.cz/cs/o-nas/aktuality/Akademie-ved-CR-ziskala-Cenu-rektora-Ceske-zemedelske-univerzity-v-Praze/>https://www.avcr.cz/cs/o-nas/aktuality/Akademie-ved-CR-ziskala-Cenu-rektora-Ceske-zemedelske-univerzity-v-Praze/</a></li></ul>
#     </div>
#     <img src="http://pbs.twimg.com/media/FRSAyM4XMAAOVW3.jpg" alt="img">
# </div>
#
# <div class=item>
#     <h3>Computer Science</h3><h5>2022-04-26 15:45:06+00:00</h5>
#     <div class=text>
#     Dijkstra manuscript archive https://t.co/MlOZHZC5nc
#     <h4>Uris:</h4><ul><li><a href=http://www.cs.utexas.edu/users/EWD/>http://www.cs.utexas.edu/users/EWD/</a></li></ul>
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Science Tip</h3><h5>2022-04-26 15:40:02+00:00</h5>
#     <div class=text>
#     Standard model particles are divided into quarks, leptons, and bosons.
#
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Regular Expression</h3><h5>2022-04-26 15:02:03+00:00</h5>
#     <div class=text>
#     The greatest regex trick ever https://t.co/geQ79RIN1H
#     <h4>Uris:</h4><ul><li><a href=http://www.rexegg.com/regex-best-trick.html>http://www.rexegg.com/regex-best-trick.html</a></li></ul>
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Data Science Fact</h3><h5>2022-04-26 14:55:02+00:00</h5>
#     <div class=text>
#     The wiggle paradox https://t.co/hfCImoihqK
#     <h4>Uris:</h4><ul><li><a href=https://www.johndcook.com/blog/2012/01/31/wiggle-paradox/>https://www.johndcook.com/blog/2012/01/31/wiggle-paradox/</a></li></ul>
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Rekonstrukce státu</h3><h5>2022-04-26 14:54:50+00:00</h5>
#     <div class=text>
#     Za chvilku začínáme - připojte se na linku níže ⬇️ https://t.co/OnTAJ46Egs
#     <h4>Uris:</h4><ul><li><a href=https://twitter.com/RekonstrukceCZ/status/1518596329831899138>https://twitter.com/RekonstrukceCZ/status/1518596329831899138</a></li></ul>
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>TeX and Typography</h3><h5>2022-04-26 14:45:05+00:00</h5>
#     <div class=text>
#     How to put PDF properties in a LaTeX file https://t.co/ZiHcty109Q
#     <h4>Uris:</h4><ul><li><a href=https://www.johndcook.com/blog/2008/11/24/how-to-put-pdf-properties-in-a-latex-file/>https://www.johndcook.com/blog/2008/11/24/how-to-put-pdf-properties-in-a-latex-file/</a></li></ul>
#     </div>
#
# </div>
#
# <div class=item>
#     <h3>Probability Fact</h3><h5>2022-04-26 13:25:37+00:00</h5>
#     <div class=text>
#     “It Took Me 10 Years to Understand Entropy, Here is What I Learned.”
#
# https://t.co/te1pxuCdlD
#     <h4>Uris:</h4><ul><li><a href=https://www.cantorsparadise.com/it-took-me-10-years-to-understand-entropy-here-is-what-i-learned-b2d51e8ccd4c>https://www.cantorsparadise.com/it-took-me-10-years-to-understand-entropy-here-is-what-i-learned-b2d51e8ccd4c</a></l
